# %% [markdown]
# # 📊 Phase 2: Exploratory Data Analysis
# ## Visualizing Dataset Characteristics and Distributions

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from config import DATA_DIR
from src.data.dataset import LeafDataset
from src.utils.visualization import Visualizer

dataset = LeafDataset(DATA_DIR)
dataset.investigate()
class_names = dataset.class_names
viz = Visualizer()

# %%
# 1. Class Distribution
viz.plot_class_distribution(
    dataset.class_counts,
    ['Tomato_healthy', 'Potato___healthy', 'Pepper__bell___healthy']
)

# %%
# 2. Sample Images Grid
viz.plot_sample_grid(dataset, class_names)

# %%
# 3. Dimension Analysis
viz.plot_dimension_distributions(dataset, class_names)
