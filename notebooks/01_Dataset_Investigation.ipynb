# %% [markdown]
# # 🌿 Phase 1: Dataset Investigation
# ## Leaf Disease Detection - CodeAlpha Internship
#
# This notebook explores the PlantVillage dataset structure, quality, and statistics.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from config import DATA_DIR
from src.data.dataset import LeafDataset
from src.utils.visualization import Visualizer
from src.utils.logger import setup_logger

logger = setup_logger()
viz = Visualizer()

# %%
# Initialize and investigate dataset
dataset = LeafDataset(DATA_DIR)
summary = dataset.investigate()

# %%
# View class distribution
df = dataset.get_class_dataframe()
df.head(15)

# %%
# Generate report
dataset.generate_report(Path.cwd().parent / 'reports' / 'dataset_report.md')
